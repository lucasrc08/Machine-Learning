# %% [markdown]
# """
# # Fase 1: Comprensión del Negocio (CRISP-DM)
# ## Máquina de Aprendizaje 1 — Universidad de la Sabana
#
# ### Contexto
# La industria musical vive una transformación digital donde el éxito de una canción
# ya no depende solo de la radio, sino de algoritmos en plataformas como Spotify y YouTube.
# Entender qué hace viral una canción tiene alto valor para sellos, artistas y productoras.
#
# ### Objetivo de Negocio
# Predecir la popularidad (streams) de una canción a partir de sus características musicales
# y métricas de plataformas digitales.
#
# ### Objetivos de Minería de Datos
# 1. **Regresión:** Predecir el número de streams en Spotify (variable continua `Stream`)
# 2. **Clasificación:** Predecir si una canción será "viral" (>= 500M streams → `viral = 1`)
# 3. **Clustering:** Agrupar canciones por perfil musical para descubrir segmentos

# %%
import yaml
with open("../config/config.yaml") as f:
    config = yaml.safe_load(f)
print(f"Target regresión: {config['target_regression']}")
print(f"Target clasificación: {config['target_classification']}")
print(f"Umbral viral: {config['viral_threshold']:,} streams")
# Out:
# Configuración cargada
# Target regresión: Stream
# Target clasificación: viral
# Umbral viral: 500,000,000 streams
